# %% [markdown]
# # Spam SMS Detection
#
# This project classifies SMS messages as Spam or Ham using Machine Learning.
#
# Internship: CodSoft Machine Learning Internship

# %% [markdown]
# Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %% [markdown]
# Upload Kaggle dataset

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-e6cacacb-1833-428d-8d6d-2441e10c7ec6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e6cacacb-1833-428d-8d6d-2441e10c7ec6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Unzip the file

# %%
import zipfile

with zipfile.ZipFile("archive (5) (1).zip", "r") as zip_ref:
    zip_ref.extractall()

print("Dataset extracted successfully!")
# Out:
# Dataset extracted successfully!

# %% [markdown]
# Check Files

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'archive (5) (1).zip', 'spam.csv', 'archive (5).zip', 'sample_data']

# %% [markdown]
# Load

# %%
df = pd.read_csv("spam.csv", encoding="latin-1")

# %% [markdown]
# Keep only useful columns

# %%
df = df[['v1', 'v2']]

df.columns = ['label', 'message']

df.head()
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# Check Dataset

# %%
print("Rows and Columns:")
print(df.shape)

print("\nMissing Values:")
print(df.isnull().sum())

print("\nSpam vs Ham:")
print(df['label'].value_counts())
# Out:
# Rows and Columns:
# (5572, 2)
#
# Missing Values:
# label      0
# message    0
# dtype: int64
#
# Spam vs Ham:
# label
# ham     4825
# spam     747
# Name: count, dtype: int64

# %% [markdown]
# Convert Labels into Numbers

# %%
df['label'] = df['label'].map({
    'ham': 0,
    'spam': 1
})

df.head()
# Out:
#    label                                            message
# 0      0  Go until jurong point, crazy.. Available only ...
# 1      0                      Ok lar... Joking wif u oni...
# 2      1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      0  U dun say so early hor... U c already then say...
# 4      0  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# Prepare Features and Labels

# %%
X = df['message']
y = df['label']

print(X.head())

print("\n")

print(y.head())
# Out:
# 0    Go until jurong point, crazy.. Available only ...
# 1                        Ok lar... Joking wif u oni...
# 2    Free entry in 2 a wkly comp to win FA Cup fina...
# 3    U dun say so early hor... U c already then say...
# 4    Nah I don't think he goes to usf, he lives aro...
# Name: message, dtype: object
#
#
# 0    0
# 1    0
# 2    1
# 3    0
# 4    0
# Name: label, dtype: int64

# %% [markdown]
# Convert Text into Numbers (TF-IDF)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(
    stop_words='english',
    max_features=5000
)

X_tfidf = tfidf.fit_transform(X)

print(X_tfidf.shape)
# Out:
# (5572, 5000)

# %% [markdown]
# Train-Test Split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_tfidf,
    y,
    test_size=0.2,
    random_state=42
)

print(X_train.shape)
print(X_test.shape)
# Out:
# (4457, 5000)
# (1115, 5000)

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

lr_model = LogisticRegression(max_iter=1000)

lr_model.fit(X_train, y_train)

lr_pred = lr_model.predict(X_test)

lr_accuracy = accuracy_score(y_test, lr_pred)

print("Logistic Regression Accuracy:", lr_accuracy)
# Out:
# Logistic Regression Accuracy: 0.9488789237668162

# %% [markdown]
# Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB

nb_model = MultinomialNB()

nb_model.fit(X_train, y_train)

nb_pred = nb_model.predict(X_test)

nb_accuracy = accuracy_score(y_test, nb_pred)

print("Naive Bayes Accuracy:", nb_accuracy)
# Out:
# Naive Bayes Accuracy: 0.9748878923766816

# %% [markdown]
# SVM

# %%
from sklearn.svm import LinearSVC

svm_model = LinearSVC()

svm_model.fit(X_train, y_train)

svm_pred = svm_model.predict(X_test)

svm_accuracy = accuracy_score(y_test, svm_pred)

print("SVM Accuracy:", svm_accuracy)
# Out:
# SVM Accuracy: 0.9739910313901345

# %% [markdown]
# Compare Models

# %%
print("Logistic Regression Accuracy:", lr_accuracy)
print("Naive Bayes Accuracy:", nb_accuracy)
print("SVM Accuracy:", svm_accuracy)
# Out:
# Logistic Regression Accuracy: 0.9488789237668162
# Naive Bayes Accuracy: 0.9748878923766816
# SVM Accuracy: 0.9739910313901345

# %% [markdown]
# Best Model

# %%
model_accuracies = {
    "Logistic Regression": lr_accuracy,
    "Naive Bayes": nb_accuracy,
    "SVM": svm_accuracy
}

best_model_name = max(model_accuracies, key=model_accuracies.get)
best_accuracy = model_accuracies[best_model_name]

print("Best Model:", best_model_name)
print("Best Accuracy:", best_accuracy)
# Out:
# Best Model: Naive Bayes
# Best Accuracy: 0.9748878923766816

# %% [markdown]
# Save Model

# %%
import joblib

joblib.dump(nb_model, "spam_sms_model.pkl")
joblib.dump(tfidf, "tfidf_vectorizer.pkl")

print("Model saved successfully!")
# Out:
# Model saved successfully!

# %% [markdown]
# Download

# %%
from google.colab import files

files.download("spam_sms_model.pkl")
files.download("tfidf_vectorizer.pkl")

# %% [markdown]
# Test_1

# %%
sample_sms = ["Congratulations! You have won a free lottery prize. Click here to claim now."]

sample_tfidf = tfidf.transform(sample_sms)

prediction = nb_model.predict(sample_tfidf)

if prediction[0] == 1:
    print("Spam Message")
else:
    print("Ham Message")
# Out:
# Spam Message

# %% [markdown]
# Test_2

# %%
sample_sms = ["Hey, are you coming to class tomorrow?"]

sample_tfidf = tfidf.transform(sample_sms)

prediction = nb_model.predict(sample_tfidf)

if prediction[0] == 1:
    print("Spam Message")
else:
    print("Ham Message")
# Out:
# Ham Message

# %% [markdown]
# Test_3

# %%
sample_sms = ["Hey, I have reached home safely. Thanks for helping me today!"]
sample_tfidf = tfidf.transform(sample_sms)

prediction = nb_model.predict(sample_tfidf)

if prediction[0] == 1:
    print("Spam Message")
else:
    print("Ham Message")
# Out:
# Ham Message

# %% [markdown]
# **CONCLUSION**:
#
# This project classifies SMS messages as Spam or Ham using Machine Learning and TF-IDF vectorization.
#
# Three machine learning models were trained and compared:
# 1. Logistic Regression
# 2. Naive Bayes
# 3. Support Vector Machine (SVM)
#
# The Naive Bayes model achieved the highest accuracy of 97.49%, outperforming the other models. The final model can successfully identify spam messages and help filter unwanted SMS communications.
